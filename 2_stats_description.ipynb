# %%
# Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import utils as eda

# Dataset
total_data = pd.read_csv(r'C:\Users\ThinkPad-PC\Documents\GitHub\won_analysis\datasets\days_to_start_data.csv',index_col=None)

# %% [markdown]
# Note: The 'utils.py' file contains specific functions according to the standards of Exploratory Data Analysis (EDA) and Descriptive Data Analysis (DDA). The functions with the prefix 'eda' are described in the 'utils.py' doc.

# %%
# general info and shape
total_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 944 entries, 0 to 943
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Program            944 non-null    object
#  1   buy_date           944 non-null    object
#  2   cohort_start_date  944 non-null    object
#  3   cohort_name        944 non-null    object
#  4   days_to_start      944 non-null    int64
#  5   month_sale         944 non-null    int64
#  6   month_start        944 non-null    int64
# dtypes: int64(3), object(4)
# memory usage: 51.8+ KB

# %%
# General description and data values 
total_data.describe().T
# Out:
#                count       mean        std  min   25%   50%   75%    max
# days_to_start  944.0  67.620763  52.365550  0.0  35.0  54.0  81.0  675.0
# month_sale     944.0   6.623941   3.202514  1.0   4.0   7.0   9.0   12.0
# month_start    944.0   7.111229   3.508106  1.0   4.0   9.0  10.0   12.0

# %%
# Plot numerical variables to see values distribution (mean, median, std, outliers)
eda.plot_numerical_data(total_data)
