# %%
import pandas as pd
import numpy as np


# CRM DATASET
crm_sales = pd.read_csv(r'..\won_analysis\all_spain_leads.csv')

# MKT DATASET
mkt_sales =pd.read_csv(r'..\won_analysis\won_date.csv')

# ADM DATASET
adm_sales =pd.read_csv(r'..\won_analysis\cohorts.csv')
# Out:
# C:\Users\ThinkPad-PC\AppData\Local\Temp\ipykernel_3572\1420789369.py:6: DtypeWarning: Columns (17,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   crm_sales = pd.read_csv(r'..\won_analysis\all_spain_leads.csv')

# %%
import pandas as pd

# Asegúrate de que la columna 'created_at' sea de tipo datetime
crm_sales['created_at'] = pd.to_datetime(crm_sales['created_at'])

# Ordenar por la columna 'created_at'
crm_sales_sorted = crm_sales.sort_values(by='created_at')

# crear subcojunto
mask = ['email','created_at']

# Si solo deseas ordenar el subconjunto filtrado (mask)
crm_sales_sorted_mask = crm_sales[mask].sort_values(by='created_at').drop_duplicates(keep='first')

# %%
crm_sales_sorted_mask.head(20)
# Out:
#                                    email                       created_at
# 13811              rimoreno493@gmail.com 2020-09-22 14:40:44.677356+00:00
# 4572              ingsuarezcda@gmail.com 2020-09-22 15:48:03.107909+00:00
# 658                 edpago86@hotmail.com 2020-09-22 21:07:13.802404+00:00
# 1241                   nmoreno@4geeks.co 2020-09-23 08:25:22.232708+00:00
# 4                   ali-hourag@gmail.com 2020-09-23 14:42:17.182823+00:00
# 1257                kikidaviss@gmail.com 2020-09-23 23:12:32.996976+00:00
# 5                 REVERONFELIX@GMAIL.COM 2020-09-24 19:58:17.610143+00:00
# 1050               borjita1091@gmail.com 2020-09-26 12:29:28.934470+00:00
# 4430                borjaarmet@gmail.com 2020-09-28 09:06:16.005559+00:00
# 8                   dbraccipro@gmail.com 2020-09-29 20:16:16.240585+00:00
# 4678              hydraiciar@hotmail.com 2020-10-01 11:50:20.277693+00:00
# 9               rafaelagcalves@gmail.com 2020-10-01 13:21:54.537748+00:00
# ...
